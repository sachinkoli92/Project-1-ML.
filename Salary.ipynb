# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
salary=pd.read_csv('salarydata.csv')

# %%
salary
# Out:
#      Emp ID Name Prefix First Name Middle Initial  Last Name Gender  \
# 0    850297         Ms.     Shawna              W       Buck      F
# 1    304721         Mr.  Nathaniel              Z      Burke      M
# 2    412317        Drs.  Elisabeth              W     Foster      F
# 3    621375        Mrs.     Briana              C  Lancaster      F
# 4    787549        Hon.    Estella              L     Potter      F
# ..      ...         ...        ...            ...        ...    ...
# 995  568435         Ms.     Bonnie              K      Baker      F
# 996  597409         Mr.       Luke              S     Turner      M
# 997  359608        Hon.        Eva              S     Holman      F
# 998  803426        Mrs.    Maritza              H  Christian      F
# 999  669618        Drs.    Phyllis              H     Dudley      F
#
#                               E Mail      Father's Name        Mother's Name  \
# ...

# %%
salary.columns
# Out:
# Index(['Emp ID', 'Name Prefix', 'First Name', 'Middle Initial', 'Last Name',
#        'Gender', 'E Mail', 'Father's Name', 'Mother's Name',
#        'Mother's Maiden Name', 'Date of Birth', 'Time of Birth', 'Age in Yrs.',
#        'Weight in Kgs.', 'Date of Joining', 'Quarter of Joining',
#        'Half of Joining', 'Year of Joining', 'Month of Joining',
#        'Month Name of Joining', 'Short Month', 'Day of Joining',
#        'DOW of Joining', 'Short DOW', 'Age in Company (Years)', 'Salary',
#        'Last % Hike', 'SSN', 'Phone No. ', 'Place Name', 'County', 'City',
#        'State', 'Zip', 'Region', 'User Name', 'Password'],
#       dtype='object')

# %%
data=salary.drop(['Emp ID','Name Prefix','First Name','Middle Initial','Last Name','E Mail',"Father's Name","Mother's Name","Mother's Maiden Name","Date of Birth",'Time of Birth','Weight in Kgs.',"SSN",'Phone No. ','Place Name','County','City',
                 'State','Zip','Region','User Name','Password'],axis=1)

# %%
data
# Out:
#     Gender  Age in Yrs. Date of Joining Quarter of Joining Half of Joining  \
# 0        F        45.66      12/18/2010                 Q4              H2
# 1        M        23.76       4/25/2017                 Q2              H1
# 2        F        22.68       3/27/2017                 Q1              H1
# 3        F        41.70       2/25/2003                 Q1              H1
# 4        F        22.39      10/11/2016                 Q4              H2
# ..     ...          ...             ...                ...             ...
# 995      F        32.01        1/7/2008                 Q1              H1
# 996      M        30.48        3/5/2010                 Q1              H1
# 997      F        59.88       2/20/2001                 Q1              H1
# 998      F        30.21       3/15/2012                 Q1              H1
# 999      F        59.78       1/17/1980                 Q1              H1
#
# ...

# %%
data.drop(['Date of Joining','Month Name of Joining','Short Month','DOW of Joining'],axis=1,inplace=True)

# %%
data
# Out:
#     Gender  Age in Yrs. Quarter of Joining Half of Joining  Year of Joining  \
# 0        F        45.66                 Q4              H2             2010
# 1        M        23.76                 Q2              H1             2017
# 2        F        22.68                 Q1              H1             2017
# 3        F        41.70                 Q1              H1             2003
# 4        F        22.39                 Q4              H2             2016
# ..     ...          ...                ...             ...              ...
# 995      F        32.01                 Q1              H1             2008
# 996      M        30.48                 Q1              H1             2010
# 997      F        59.88                 Q1              H1             2001
# 998      F        30.21                 Q1              H1             2012
# 999      F        59.78                 Q1              H1             1980
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder=LabelEncoder()

# %%
list=["Gender","Quarter of Joining","Half of Joining","Short DOW"]
for i in list:
    data[i]=encoder.fit_transform(data[i].astype(str))

# %%
data
# Out:
#      Gender  Age in Yrs.  Quarter of Joining  Half of Joining  \
# 0         0        45.66                   3                1
# 1         1        23.76                   1                0
# 2         0        22.68                   0                0
# 3         0        41.70                   0                0
# 4         0        22.39                   3                1
# ..      ...          ...                 ...              ...
# 995       0        32.01                   0                0
# 996       1        30.48                   0                0
# 997       0        59.88                   0                0
# 998       0        30.21                   0                0
# 999       0        59.78                   0                0
#
#      Year of Joining  Month of Joining  Day of Joining  Short DOW  \
# 0               2010                12              18          2
# 1               2017                 4              25          5
# ...

# %% [markdown]
# # Exploratory Data Analaysis

# %%
data.describe()
# Out:
#             Gender  Age in Yrs.  Quarter of Joining  Half of Joining  \
# count  1000.000000  1000.000000         1000.000000      1000.000000
# mean      0.509000    40.377250            1.489000         0.481000
# std       0.500169    11.107729            1.113157         0.499889
# min       0.000000    21.040000            0.000000         0.000000
# 25%       0.000000    30.925000            1.000000         0.000000
# 50%       1.000000    40.730000            1.000000         0.000000
# 75%       1.000000    49.852500            3.000000         1.000000
# max       1.000000    59.980000            3.000000         1.000000
#
#        Year of Joining  Month of Joining  Day of Joining    Short DOW  \
# count      1000.000000       1000.000000     1000.000000  1000.000000
# mean       2006.992000          6.415000       16.481000     2.925000
# std           8.565588          3.428488        8.831514     2.008335
# ...

# %%
sns.barplot(x='Gender',y='Salary',data=data)

# %%
plt.figure(figsize=(30,30))
sns.barplot(x='Age in Yrs.',y='Salary',data=data)

# %%
data.corr()
# Out:
#                           Gender  Age in Yrs.  Quarter of Joining  \
# Gender                  1.000000    -0.013794            0.016359
# Age in Yrs.            -0.013794     1.000000            0.020401
# Quarter of Joining      0.016359     0.020401            1.000000
# Half of Joining        -0.011326     0.023395            0.893673
# Year of Joining         0.047214    -0.676875           -0.032659
# Month of Joining        0.015040     0.022617            0.971525
# Day of Joining         -0.002001    -0.026387            0.034191
# Short DOW               0.062954     0.018045           -0.059249
# Age in Company (Years) -0.047735     0.676408            0.000146
# Salary                  0.050883     0.041422           -0.015299
#
#                         Half of Joining  Year of Joining  Month of Joining  \
# Gender                        -0.011326         0.047214          0.015040
# Age in Yrs.                    0.023395        -0.676875          0.022617
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(data.corr(),cmap="YlGnBu",annot=True)

# %% [markdown]
# In heatmap above, the data that has almost no correlation with Salary are Half of Joining, Last% Hike

# %%
sns.barplot(x='Last % Hike',y="Salary",data=data)

# %%
data.drop(['Last % Hike','Half of Joining','Quarter of Joining','Year of Joining','Day of Joining','Short DOW', 'Month of Joining'],axis=1,inplace=True)

# %%
data
# Out:
#      Gender  Age in Yrs.  Age in Company (Years)  Salary
# 0         0        45.66                    6.61  119090
# 1         1        23.76                    0.26  117991
# 2         0        22.68                    0.34  161045
# 3         0        41.70                   14.43  142616
# 4         0        22.39                    0.79  135706
# ..      ...          ...                     ...     ...
# 995       0        32.01                    9.56   72930
# 996       1        30.48                    7.40  121949
# 997       0        59.88                   16.44   82734
# 998       0        30.21                    5.37   66854
# 999       0        59.78                   37.55  105069
#
# [1000 rows x 4 columns]

# %%
data.isnull().sum()
# Out:
# Gender                    0
# Age in Yrs.               0
# Age in Company (Years)    0
# Salary                    0
# dtype: int64

# %%
data.skew()
# Out:
# Gender                   -0.036060
# Age in Yrs.               0.006173
# Age in Company (Years)    0.968211
# Salary                    0.034356
# dtype: float64

# %%
x=data.iloc[:,0:-1]

# %%
x
# Out:
#      Gender  Age in Yrs.  Age in Company (Years)
# 0         0        45.66                    6.61
# 1         1        23.76                    0.26
# 2         0        22.68                    0.34
# 3         0        41.70                   14.43
# 4         0        22.39                    0.79
# ..      ...          ...                     ...
# 995       0        32.01                    9.56
# 996       1        30.48                    7.40
# 997       0        59.88                   16.44
# 998       0        30.21                    5.37
# 999       0        59.78                   37.55
#
# [1000 rows x 3 columns]

# %%
y=data.iloc[:,-1]

# %%
y
# Out:
# 0      119090
# 1      117991
# 2      161045
# 3      142616
# 4      135706
#         ...
# 995     72930
# 996    121949
# 997     82734
# 998     66854
# 999    105069
# Name: Salary, Length: 1000, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
a=[LinearRegression(),DecisionTreeRegressor(),KNeighborsRegressor(),SVR()]
for j in a:
    max_r_score=0
    print('for the algorithm :',j)
    for i in range(33,101):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=.20)
        j.fit(x_train,y_train)
        pred=j.predict(x_test)
        score=j.score(x_train,y_train)
        r2_scr=r2_score(pred,y_test)
        print('r2 score corresponding to random state',i,'is: ',r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final=i
            
    print('\n')
    print('Max accuracy score corresponding to: ', final,'is: ',max_r_score)
    print('\n')
# Out:
# for the algorithm : LinearRegression()
# r2 score corresponding to random state 33 is:  -209.4646466694273
# r2 score corresponding to random state 34 is:  -85.82148762528911
# r2 score corresponding to random state 35 is:  -151.1032070345198
# r2 score corresponding to random state 36 is:  -138.34734901173778
# r2 score corresponding to random state 37 is:  -258.2745810675576
# r2 score corresponding to random state 38 is:  -120.03912664855464
# r2 score corresponding to random state 39 is:  -195.81484641394516
# r2 score corresponding to random state 40 is:  -120.76715520080853
# r2 score corresponding to random state 41 is:  -146.2339467779171
# r2 score corresponding to random state 42 is:  -112.2599462583726
# r2 score corresponding to random state 43 is:  -154.91378273948303
# r2 score corresponding to random state 44 is:  -188.54948595075746
# r2 score corresponding to random state 45 is:  -125.21294400440703
# ...
